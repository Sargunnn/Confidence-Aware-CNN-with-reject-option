# %% [markdown]
# <a href="https://colab.research.google.com/github/Sargunnn/Confidence-Aware-CNN-with-reject-option/blob/main/Assignment1(DL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class Perceptron:
    def __init__(self, learning_rate=0.1, epochs=20):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def activation(self, x):
        return 1 if x >= 0 else 0

    def fit(self, X, y):
        n_samples, n_features = X.shape

        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.epochs):
            for i in range(n_samples):
                linear_output = np.dot(X[i], self.weights) + self.bias
                y_pred = self.activation(linear_output)

                error = y[i] - y_pred

                self.weights += self.lr * error * X[i]
                self.bias += self.lr * error

    def predict(self, X):
        predictions = []
        for x in X:
            linear_output = np.dot(x, self.weights) + self.bias
            predictions.append(self.activation(linear_output))
        return predictions

X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

gates = {
    "AND":  np.array([0, 0, 0, 1]),
    "OR":   np.array([0, 1, 1, 1]),
    "NAND": np.array([1, 1, 1, 0]),
    "NOR":  np.array([1, 0, 0, 0]),
    "XOR":  np.array([0, 1, 1, 0])
}

# %%
for name, y in gates.items():
    print("\n==========", name, "Gate ==========")

    model = Perceptron(learning_rate=0.1, epochs=20)
    model.fit(X, y)

    predictions = model.predict(X)

    print("Final Weights:", model.weights)
    print("Final Bias:", model.bias)
    print("Predictions:", predictions)
    print("Actual:", y.tolist())

    if predictions == y.tolist():
        print("✔ Learned Successfully")
    else:
        print("✘ Not Learned (Not Linearly Separable)")
# Out:
# ========== AND Gate ==========
# Final Weights: [0.2 0.1]
# Final Bias: -0.20000000000000004
# Predictions: [0, 0, 0, 1]
# Actual: [0, 0, 0, 1]
# ✔ Learned Successfully
#
# ========== OR Gate ==========
# Final Weights: [0.1 0.1]
# Final Bias: -0.1
# Predictions: [0, 1, 1, 1]
# Actual: [0, 1, 1, 1]
# ✔ Learned Successfully
#
# ========== NAND Gate ==========
# Final Weights: [-0.2 -0.1]
# Final Bias: 0.2
# Predictions: [1, 1, 1, 0]
# Actual: [1, 1, 1, 0]
# ✔ Learned Successfully
#
# ========== NOR Gate ==========
# Final Weights: [-0.1 -0.1]
# Final Bias: 0.0
# Predictions: [1, 0, 0, 0]
# Actual: [1, 0, 0, 0]
# ✔ Learned Successfully
#
# ========== XOR Gate ==========
# Final Weights: [-0.1  0. ]
# Final Bias: 0.0
# Predictions: [1, 1, 0, 0]
# Actual: [0, 1, 1, 0]
# ✘ Not Learned (Not Linearly Separable)

# %%
# !git clone https://github.com/Sargunnn/Confidence-Aware-CNN-with-reject-option.git
# Out:
# Cloning into 'Confidence-Aware-CNN-with-reject-option'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !mv "Assignment1(DL).ipynb" Confidence-Aware-CNN-with-reject-option/
# Out:
# mv: cannot stat 'Assignment1(DL).ipynb': No such file or directory

# %%
# %cd Confidence-Aware-CNN-with-reject-option
# Out:
# /content/Confidence-Aware-CNN-with-reject-option

# %%
# !git config --global user.email "kaursarg7n@gmail.com"
# !git config --global user.name "Sargunnn"

# %%
# !git add .
# !git commit -m "Added Assignment1"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
